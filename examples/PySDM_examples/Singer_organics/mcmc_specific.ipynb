# %%
from PySDM_examples.Singer_organics.mcmc_generic import mcmc_generic
# mcmc_generic(filename="bcary_dark.csv", model="CompressedFilmOvadnevaite", n_steps=300)
mcmc_generic(filename="bcary_dark.csv", model="SzyszkowskiLangmuir", n_steps=1000)
# mcmc_generic(filename="bcary_dark.csv", model="CompressedFilmRuehl", n_steps=1000)


# import os
# os.environ["NUMBA_DISABLE_JIT"] = "1"

# N = 500
# mcmc_generic(filename="bcary_dark.csv", model="CompressedFilmOvadnevaite", n_steps=N*2, plot=True)
# mcmc_generic(filename="bcary_dark.csv", model="SzyszkowskiLangmuir", n_steps=N*3, plot=True)
# mcmc_generic(filename="bcary_dark.csv", model="CompressedFilmRuehl", n_steps=N*4, plot=True)
# Out:
# initial params: [7.5e-19, -15, 0.025] 	 = 	 [7.50000000e-19 3.05902321e-07 2.50000000e-02]
# final params: [ 7.79278114e-19 -1.32440073e+01  2.88245637e-02] 	 = 	 [7.79278114e-19 1.77092717e-06 2.88245637e-02]
# HTML(value="<a href='./bcary_dark_SL_n1000_chain.pdf' target='_blank'>./bcary_dark_SL_n1000_chain.pdf</a><br>"…
# HTML(value="<a href='./bcary_dark_SL_n1000_corner.pdf' target='_blank'>./bcary_dark_SL_n1000_corner.pdf</a><br…
